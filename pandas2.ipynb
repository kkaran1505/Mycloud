# %%
import pandas as pd

# %%
filepath=r"C:\Users\MY\Desktop\Stock.csv"

# %%
df= pd.read_csv(filepath)

# %%
df
# Out:
#    ticker            eps   revenue  price          people
# 0  google           27.82        87    842     larry page
# 1      WMT           4.61       484     65            n.a
# 2     MSFT             -1        85     64     bill gates
# 3      RIL  not available        50   1023  mukesh ambani
# 4     TATA            5.6        -1    n.a     ratan tata

# %%
df= pd.read_csv(filepath,skiprows=1)# skiprows=1 or header=1

# %%
df
# Out:
#    ticker            eps   revenue  price          people
# 0  google           27.82        87    842     larry page
# 1      WMT           4.61       484     65            n.a
# 2     MSFT             -1        85     64     bill gates
# 3      RIL  not available        50   1023  mukesh ambani
# 4     TATA            5.6        -1    n.a     ratan tata

# %%
df= pd.read_csv(filepath,nrows=3)# read only 3 rows

# %%
df
# Out:
#   stock header Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0      ticker        eps    revenue      price       people
# 1      google       27.82         87        842  larry page
# 2          WMT       4.61        484         65         n.a

# %%
df= pd.read_csv(filepath,na_values=["not available","n.a"])# replace not available and n.a by NaN

# %%
df
# Out:
#   stock header Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0      ticker        eps    revenue      price          people
# 1      google       27.82         87        842     larry page
# 2          WMT       4.61        484         65            NaN
# 3         MSFT         -1         85         64     bill gates
# 4          RIL        NaN         50       1023  mukesh ambani
# 5         TATA        5.6         -1        NaN     ratan tata

# %%
df= pd.read_csv(filepath,na_values={ revenue: ["not available","n.a",-1]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\3981774987.py in <module>
# ----> 1 df= pd.read_csv(filepath,na_values={ revenue: ["not available","n.a",-1]})
#
# NameError: name 'revenue' is not defined

# %%
df= pd.read_csv(filepath)

# %%
df
# Out:
#    ticker            eps   revenue  price          people
# 0  google           27.82        87    842     larry page
# 1      WMT           4.61       484     65            n.a
# 2     MSFT             -1        85     64     bill gates
# 3      RIL  not available        50   1023  mukesh ambani
# 4     TATA            5.6        -1    n.a     ratan tata

# %%
df= pd.read_csv(filepath,na_values=["not available","n.a"])

# %%
df
# Out:
#    ticker    eps   revenue   price          people
# 0  google   27.82        87   842.0     larry page
# 1      WMT   4.61       484    65.0            NaN
# 2     MSFT  -1.00        85    64.0     bill gates
# 3      RIL    NaN        50  1023.0  mukesh ambani
# 4     TATA   5.60        -1     NaN     ratan tata

# %%
df= pd.read_csv(filepath,na_values = { 
    "revenue": ["not available","n.a",-1],
    "eps":["not available","n.a"],
    "price":["not available","n.a"],
    "people":["not available","n.a"]
})
df
# Out:
#    ticker            eps   revenue  price          people
# 0  google           27.82        87    842     larry page
# 1      WMT           4.61       484     65            NaN
# 2     MSFT             -1        85     64     bill gates
# 3      RIL  not available        50   1023  mukesh ambani
# 4     TATA            5.6        -1    n.a     ratan tata

# %%
# Out:
#    ticker            eps   revenue  price          people
# 0  google           27.82        87    842     larry page
# 1      WMT           4.61       484     65            NaN
# 2     MSFT             -1        85     64     bill gates
# 3      RIL  not available        50   1023  mukesh ambani
# 4     TATA            5.6        -1    n.a     ratan tata

# %%
df= pd.read_csv(filepath,na_values=["not available","n.a"])
df
# Out:
#    ticker    eps   revenue   price          people
# 0  google   27.82        87   842.0     larry page
# 1      WMT   4.61       484    65.0            NaN
# 2     MSFT  -1.00        85    64.0     bill gates
# 3      RIL    NaN        50  1023.0  mukesh ambani
# 4     TATA   5.60        -1     NaN     ratan tata

# %%
df
# Out:
#    ticker    eps   revenue   price          people
# 0  google   27.82        87   842.0     larry page
# 1      WMT   4.61       484    65.0            NaN
# 2     MSFT  -1.00        85    64.0     bill gates
# 3      RIL    NaN        50  1023.0  mukesh ambani
# 4     TATA   5.60        -1     NaN     ratan tata

# %%
df= pd.read_csv(filepath,na_values={"revenue": ["not available","n.a",-1]})
df
# Out:
#    ticker            eps   revenue  price          people
# 0  google           27.82        87    842     larry page
# 1      WMT           4.61       484     65            n.a
# 2     MSFT             -1        85     64     bill gates
# 3      RIL  not available        50   1023  mukesh ambani
# 4     TATA            5.6        -1    n.a     ratan tata

# %%
df= pd.read_csv(filepath,na_values=["not available","n.a"])
df
# Out:
#    ticker    eps   revenue   price          people
# 0  google   27.82        87   842.0     larry page
# 1      WMT   4.61       484    65.0            NaN
# 2     MSFT  -1.00        85    64.0     bill gates
# 3      RIL    NaN        50  1023.0  mukesh ambani
# 4     TATA   5.60        -1     NaN     ratan tata

# %%
df= pd.read_csv(filepath,na_values={'revenue': '-1'})
df
# Out:
#    ticker            eps   revenue  price          people
# 0  google           27.82        87    842     larry page
# 1      WMT           4.61       484     65            n.a
# 2     MSFT             -1        85     64     bill gates
# 3      RIL  not available        50   1023  mukesh ambani
# 4     TATA            5.6        -1    n.a     ratan tata

# %%
df= pd.read_csv(filepath,na_values=["not available","n.a"])
df
# Out:
#    ticker    eps   revenue   price          people
# 0  google   27.82        87   842.0     larry page
# 1      WMT   4.61       484    65.0            NaN
# 2     MSFT  -1.00        85    64.0     bill gates
# 3      RIL    NaN        50  1023.0  mukesh ambani
# 4     TATA   5.60        -1     NaN     ratan tata
